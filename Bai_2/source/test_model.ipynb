# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os

# %%
DNN_model = tf.keras.models.load_model('C:\Th-th-ch-BAI-Labs\Bai_2\model\\best_model_DNN.keras')
CNN_model = tf.keras.models.load_model('C:\Th-th-ch-BAI-Labs\Bai_2\model\\best_model_CNN.keras')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20540\919045153.py:1: SyntaxWarning: invalid escape sequence '\T'
#   DNN_model = tf.keras.models.load_model('C:\Th-th-ch-BAI-Labs\Bai_2\model\\best_model_DNN.keras')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20540\919045153.py:2: SyntaxWarning: invalid escape sequence '\T'
#   CNN_model = tf.keras.models.load_model('C:\Th-th-ch-BAI-Labs\Bai_2\model\\best_model_CNN.keras')

# %%
file_number = 1
while os.path.isfile(f'C:\Th-th-ch-BAI-Labs\Bai_2\data_test\\test_{file_number}.png'):
    img = cv2.imread(f'C:\Th-th-ch-BAI-Labs\Bai_2\data_test\\test_{file_number}.png')[:, :, 1]
    img = np.invert(img).reshape(1, 28, 28)
    prediction_DNN = DNN_model.predict(img)
    print(np.argmax(prediction_DNN))
    plt.imshow(img[0], cmap = plt.cm.binary)
    file_number += 1
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20540\1124866467.py:2: SyntaxWarning: invalid escape sequence '\T'
#   while os.path.isfile(f'C:\Th-th-ch-BAI-Labs\Bai_2\data_test\\test_{file_number}.png'):
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20540\1124866467.py:3: SyntaxWarning: invalid escape sequence '\T'
#   img = cv2.imread(f'C:\Th-th-ch-BAI-Labs\Bai_2\data_test\\test_{file_number}.png')[:, :, 1]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4
# ...

# %%
file_number = 1
while os.path.isfile(f'C:\Th-th-ch-BAI-Labs\Bai_2\data_test\\test_{file_number}.png'):
    img = cv2.imread(f'C:\Th-th-ch-BAI-Labs\Bai_2\data_test\\test_{file_number}.png')[:, :, 0]
    img = np.invert(img).reshape(1, 28, 28, 1)
    img = tf.keras.utils.normalize(img)
    prediction_CNN = CNN_model.predict(img)
    print(np.argmax(prediction_CNN))
    plt.imshow(img[0], cmap = plt.cm.binary)
    file_number += 1
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20540\1597603172.py:2: SyntaxWarning: invalid escape sequence '\T'
#   while os.path.isfile(f'C:\Th-th-ch-BAI-Labs\Bai_2\data_test\\test_{file_number}.png'):
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20540\1597603172.py:3: SyntaxWarning: invalid escape sequence '\T'
#   img = cv2.imread(f'C:\Th-th-ch-BAI-Labs\Bai_2\data_test\\test_{file_number}.png')[:, :, 0]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4
# ...
