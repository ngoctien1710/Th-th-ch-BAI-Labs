# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os

# %%
DNN_model = tf.keras.models.load_model('C:\Th-th-ch-BAI-Labs\Bai_3\model\\best_model_DNN_color.keras')
CNN_model = tf.keras.models.load_model('C:\Th-th-ch-BAI-Labs\Bai_3\model\\best_model_CNN_color.keras')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16756\994854587.py:1: SyntaxWarning: invalid escape sequence '\T'
#   DNN_model = tf.keras.models.load_model('C:\Th-th-ch-BAI-Labs\Bai_3\model\\best_model_DNN_color.keras')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16756\994854587.py:2: SyntaxWarning: invalid escape sequence '\T'
#   CNN_model = tf.keras.models.load_model('C:\Th-th-ch-BAI-Labs\Bai_3\model\\best_model_CNN_color.keras')

# %%
file_number = 1
while os.path.isfile(f'C:\Th-th-ch-BAI-Labs\Bai_3\data_test\\test_{file_number}.png'):
    img = cv2.imread(f'C:\Th-th-ch-BAI-Labs\Bai_3\data_test\\test_{file_number}.png')
    img = np.invert(img).reshape(1, 28, 28, 3)
    prediction_DNN = DNN_model.predict(img)
    print(np.argmax(prediction_DNN))
    plt.imshow(img[0], cmap = plt.cm.binary)
    file_number += 1
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16756\3233260559.py:2: SyntaxWarning: invalid escape sequence '\T'
#   while os.path.isfile(f'C:\Th-th-ch-BAI-Labs\Bai_3\data_test\\test_{file_number}.png'):
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16756\3233260559.py:3: SyntaxWarning: invalid escape sequence '\T'
#   img = cv2.imread(f'C:\Th-th-ch-BAI-Labs\Bai_3\data_test\\test_{file_number}.png')
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 3
# ...

# %%
file_number = 1
while os.path.isfile(f'C:\Th-th-ch-BAI-Labs\Bai_3\data_test\\test_{file_number}.png'):
    img = cv2.imread(f'C:\Th-th-ch-BAI-Labs\Bai_3\data_test\\test_{file_number}.png')
    img = np.invert(img).reshape(1, 28, 28, 3)
    img = tf.keras.utils.normalize(img)
    prediction_CNN = CNN_model.predict(img)
    print(np.argmax(prediction_CNN))
    plt.imshow(img[0], cmap = plt.cm.binary)
    file_number += 1
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16756\4156637725.py:2: SyntaxWarning: invalid escape sequence '\T'
#   while os.path.isfile(f'C:\Th-th-ch-BAI-Labs\Bai_3\data_test\\test_{file_number}.png'):
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16756\4156637725.py:3: SyntaxWarning: invalid escape sequence '\T'
#   img = cv2.imread(f'C:\Th-th-ch-BAI-Labs\Bai_3\data_test\\test_{file_number}.png')
# 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 8
# ...
